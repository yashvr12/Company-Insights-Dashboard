# %%
import pandas as pd
import os
import numpy as np

# %%
names = [i.split(".")[0] for i in os.listdir("data")]
names
# Out:
# ['ahmedabad',
#  'bangalore',
#  'chennai',
#  'gurugram',
#  'hyderabad',
#  'indore',
#  'jaipur',
#  'mumbai',
#  'noida',
#  'pune']

# %%
data = pd.concat([pd.read_csv(f"data/{i}.csv", index_col=0) for i in names], ignore_index=True)
data
# Out:
#                      company_name  company_rating  \
# 0              Zydus Lifesciences             4.2
# 1           Intas Pharmaceuticals             4.2
# 2                   Vodafone Idea             4.2
# 3                      TTEC India             3.8
# 4          Cadila Pharmaceuticals             3.6
# ...                           ...             ...
# 94575  Preethi Kitchen Appliances             4.2
# 94576        ACCURUB Technologies             4.0
# 94577                HLL Lifecare             3.7
# 94578             Singularity AIX             3.7
# 94579               Kgc Logistics             3.5
#
#                                               other_data
# 0      Pharma , 10k-50k Employees , Public , 72 years...
# 1      Pharma , 10k-50k Employees , Fortune India 500...
# 2      Telecom , 5k-10k Employees , Public , 6 years ...
# 3      BPO , 1k-5k Employees , Public , 40 years old ...
# 4      Pharma , 5k-10k Employees , Public , 73 years ...
# ...                                                  ...
# 94575  Electronics Manufacturing , 1k-5k Employees , ...
# 94576  Auto Components , 51-200 Employees , 13 years ...
# 94577  Healthcare , 1k-5k Employees , Central , 58 ye...
# 94578                                       Pune +2 more
# 94579                                       Pune +3 more
#
# [94580 rows x 3 columns]

# %%
other_data = data["other_data"].apply(lambda x: [i.strip() for i in x.split(",")])
other_data
# Out:
# 0        [Pharma, 10k-50k Employees, Public, 72 years o...
# 1        [Pharma, 10k-50k Employees, Fortune India 500,...
# 2        [Telecom, 5k-10k Employees, Public, 6 years ol...
# 3        [BPO, 1k-5k Employees, Public, 40 years old, A...
# 4        [Pharma, 5k-10k Employees, Public, 73 years ol...
#                                ...
# 94575    [Electronics Manufacturing, 1k-5k Employees, 4...
# 94576    [Auto Components, 51-200 Employees, 13 years o...
# 94577    [Healthcare, 1k-5k Employees, Central, 58 year...
# 94578                                       [Pune +2 more]
# 94579                                       [Pune +3 more]
# Name: other_data, Length: 94580, dtype: object

# %%
def clean_other_data(data):
    li = data.copy()

    # location
    location = li.pop().split("+")[0].strip().title()

    # years_old
    hasYears = ["years" in i.lower() for i in li]
    if True in hasYears:
        years = int(li.pop(hasYears.index(True)).split(" ")[0])
    else:
        years = np.nan

    # employees
    hasEmployees = ["employees" in i.lower() for i in li]
    if True in hasEmployees:
        employees = li.pop(hasEmployees.index(True)).replace(" Lakh", "00000").replace("k", "000").split(" ")[0]
    else:
        employees = np.nan

    # industry and type
    if len(li) == 2:
        industry = li[0]
        company_type = li[1]
    elif len(li) == 1:
        industry = li[0]
        company_type = np.nan
    else:
        industry = np.nan
        company_type = np.nan

    return {"industry": industry, "size": employees, "type": company_type, "years_old": years, "location": location}

# %%
cleaned_other_data = pd.DataFrame([clean_other_data(i) for i in other_data])
cleaned_other_data
# Out:
#                         industry         size               type  years_old  \
# 0                         Pharma  10000-50000             Public       72.0
# 1                         Pharma  10000-50000  Fortune India 500       47.0
# 2                        Telecom   5000-10000             Public        6.0
# 3                            BPO    1000-5000             Public       40.0
# 4                         Pharma   5000-10000             Public       73.0
# ...                          ...          ...                ...        ...
# 94575  Electronics Manufacturing    1000-5000                NaN       46.0
# 94576            Auto Components       51-200                NaN       13.0
# 94577                 Healthcare    1000-5000            Central       58.0
# 94578                        NaN          NaN                NaN        NaN
# 94579                        NaN          NaN                NaN        NaN
#
#         location
# 0      Ahmedabad
# 1      Ahmedabad
# 2      Ahmedabad
# 3      Ahmedabad
# 4      Ahmedabad
# ...          ...
# 94575       Pune
# 94576       Pune
# 94577       Pune
# 94578       Pune
# 94579       Pune
#
# [94580 rows x 5 columns]

# %%
'abcd'.replace("a", "b")
# Out:
# 'bbcd'

# %%
cleaned_other_data["size"].value_counts()
# Out:
# size
# 51-200          14550
# 100000+         12974
# 1000-5000        9141
# 11-50            7686
# 201-500          7335
# 501-1000         5346
# 50000-100000     3582
# 10000-50000      3231
# 5000-10000       2177
# 1-10             1091
# Name: count, dtype: int64

# %%
cleaned_data = data[["company_name", "company_rating"]].join(cleaned_other_data)
cleaned_data
# Out:
#                      company_name  company_rating                   industry  \
# 0              Zydus Lifesciences             4.2                     Pharma
# 1           Intas Pharmaceuticals             4.2                     Pharma
# 2                   Vodafone Idea             4.2                    Telecom
# 3                      TTEC India             3.8                        BPO
# 4          Cadila Pharmaceuticals             3.6                     Pharma
# ...                           ...             ...                        ...
# 94575  Preethi Kitchen Appliances             4.2  Electronics Manufacturing
# 94576        ACCURUB Technologies             4.0            Auto Components
# 94577                HLL Lifecare             3.7                 Healthcare
# 94578             Singularity AIX             3.7                        NaN
# 94579               Kgc Logistics             3.5                        NaN
#
#               size               type  years_old   location
# 0      10000-50000             Public       72.0  Ahmedabad
# 1      10000-50000  Fortune India 500       47.0  Ahmedabad
# 2       5000-10000             Public        6.0  Ahmedabad
# 3        1000-5000             Public       40.0  Ahmedabad
# 4       5000-10000             Public       73.0  Ahmedabad
# ...            ...                ...        ...        ...
# 94575    1000-5000                NaN       46.0       Pune
# 94576       51-200                NaN       13.0       Pune
# 94577    1000-5000            Central       58.0       Pune
# 94578          NaN                NaN        NaN       Pune
# 94579          NaN                NaN        NaN       Pune
#
# [94580 rows x 7 columns]

# %%
cleaned_data.drop_duplicates(inplace=True, ignore_index=True)

# %%
cleaned_data.to_csv("cleaned_data.csv")
